# %%
using Pkg

# %%
Pkg.activate()
Pkg.status();
# Out:
#   Activating project at `C:\Users\Andreas\.julia\environments\v1.11`
# Status `C:\Users\Andreas\.julia\environments\v1.11\Project.toml`
# ⌃ [46ada45e] Agents v6.2.3
# ⌃ [6e4b80f9] BenchmarkTools v1.6.0
#   [336ed68f] CSV v0.10.15
# ⌃ [13f3f980] CairoMakie v0.12.9
# ⌅ [8be319e6] Chain v0.6.0
# ⌃ [35d6a980] ColorSchemes v3.26.0
# ⌃ [a93c6f00] DataFrames v1.7.0
#   [1313f7d8] DataFramesMeta v0.15.4
# ⌅ [864edb3b] DataStructures v0.18.20
# ⌃ [31c24e10] Distributions v0.25.117
# ⌃ [634d3b9d] DrWatson v2.18.0
# ⌃ [7a1cc6ca] FFTW v1.8.1
# ⌃ [5789e2e9] FileIO v1.16.6
#   [d8961e24] FindPeaks1D v0.1.8
# ⌃ [e9467ef8] GLMakie v0.10.9
# ⌃ [7073ff75] IJulia v1.26.0
# ⌅ [a09fc81d] ImageCore v0.9.4
#   [2b14c160] ImageEdgeDetection v0.1.8
# ⌃ [6a3955dd] ImageFiltering v0.7.6
# ⌃ [787d08f9] ImageMorphology v0.4.5
#   [916415d5] Images v0.26.2
# ⌅ [a98d9a8b] Interpolations v0.14.7
# ⌅ [682c06a0] JSON v0.21.4
# ⌃ [2fda8390] LsqFit v0.15.0
#   [e94cdb99] MosaicViews v0.3.4
# ...

# %%
Pkg.add("IJulia")
# Out:
#     Updating registry at `C:\Users\Andreas\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Project.toml`
#     Updating `C:\Users\Andreas\.julia\environments\v1.11\Manifest.toml`
#   [05823500] ↑ OpenLibm_jll v0.8.1+2 ⇒ v0.8.5+0
# Precompiling project...
#     798.8 ms  ✓ Chain
#     745.7 ms  ✓ CommonSolve
#     757.2 ms  ✓ UnPack
#     742.3 ms  ✓ ManualMemory
#     796.6 ms  ✓ WorkerUtilities
#     783.1 ms  ✓ InverseFunctions
#     796.8 ms  ✓ VersionParsing
#     795.2 ms  ✓ ArrayTools
#     305.8 ms  ✓ SIMDTypes
#     349.1 ms  ✓ RealDot
#     340.2 ms  ✓ CustomUnitRanges
#     349.9 ms  ✓ SimpleBufferStream
#    1470.2 ms  ✓ ModernGL
#     504.0 ms  ✓ InlineStrings
#     520.0 ms  ✓ URIs
#     674.6 ms  ✓ Distances
#     368.6 ms  ✓ CompositionsBase
#     390.4 ms  ✓ FindPeaks1D
#     386.0 ms  ✓ InvertedIndices
#     356.7 ms  ✓ IfElse
#     847.7 ms  ✓ SpatialIndexing
# ...

# %%
using IJulia

installkernel("Julia_8_Threads", env = Dict("JULIA_NUM_THREADS"=>"8"))
# Out:
# ┌ Info: Installing Julia_8_Threads kernelspec in C:\Users\Andreas\AppData\Roaming\jupyter\kernels\julia_8_threads-1.11
# └ @ IJulia C:\Users\Andreas\.julia\packages\IJulia\dR0lE\deps\kspec.jl:105
# "C:\\Users\\Andreas\\AppData\\Roaming\\jupyter\\kernels\\julia_8_threads-1.11"

# %%
using IJulia

installkernel("Julia_16_Threads", env = Dict("JULIA_NUM_THREADS"=>"16"))
# Out:
# ┌ Info: Installing Julia_16_Threads kernelspec in C:\Users\Andreas\AppData\Roaming\jupyter\kernels\julia_16_threads-1.11
# └ @ IJulia C:\Users\Andreas\.julia\packages\IJulia\dR0lE\deps\kspec.jl:105
# "C:\\Users\\Andreas\\AppData\\Roaming\\jupyter\\kernels\\julia_16_threads-1.11"

# %%
using IJulia
installkernel("Julia_32_Threads", env = Dict("JULIA_NUM_THREADS"=>"32"))
# Out:
# ┌ Info: Installing Julia_32_Threads kernelspec in C:\Users\Andreas\AppData\Roaming\jupyter\kernels\julia_32_threads-1.11
# └ @ IJulia C:\Users\Andreas\.julia\packages\IJulia\dR0lE\deps\kspec.jl:105
# "C:\\Users\\Andreas\\AppData\\Roaming\\jupyter\\kernels\\julia_32_threads-1.11"

# %%
Pkg.add("GLMakie")
Pkg.add("Distributions")
Pkg.add("DrWatson")
Pkg.add("DataStructures")
Pkg.add("Parameters")
Pkg.add("CairoMakie")
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("ColorSchemes")
Pkg.add("DataFramesMeta")
Pkg.add("Chain")
Pkg.add("Random")
Pkg.add("JSON")
Pkg.add("Revise")
Pkg.add("BenchmarkTools")
Pkg.add("SparseArrays")
Pkg.add("Agents")
Pkg.add("Images")
Pkg.add("FFTW")
Pkg.add("FileIO")
Pkg.add("StatsBase")
Pkg.add("ImageEdgeDetection")
Pkg.add("ImageMorphology")
Pkg.add("MosaicViews")
Pkg.add("ImageFiltering")
Pkg.add("ImageCore")
Pkg.add("LsqFit")
Pkg.add("Interpolations")
Pkg.add("FindPeaks1D")
Pkg.add("StatsBase")
Pkg.add("ParallelStencil")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Andreas\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
# ...

# %%
using Agents

# %%
# Out:
# ┌ Info: Installing Julia (16 Threads) kernelspec in C:\Users\ank10ki\AppData\Roaming\jupyter\kernels\julia-_16-threads_-1.10
# └ @ IJulia C:\Users\ank10ki\.julia\packages\IJulia\Vo51o\deps\kspec.jl:105
# "C:\\Users\\ank10ki\\AppData\\Roaming\\jupyter\\kernels\\julia-_16-threads_-1.10"
